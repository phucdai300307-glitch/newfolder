# %%
a = list(map(int,input().split()))
s = 0
for i in range(len(a)):
  for j in range(i+1, len(a)):
    if a[i] > a[j]:
      break
  b = a[i] * (j-i)
  if b > s:
      s = b
print(s)
# Out:
# 4 5 6 7 1 8
# 16
